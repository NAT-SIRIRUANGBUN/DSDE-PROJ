# %%
import pandas as pd
import numpy as np
import json

# %%
pd.options.display.max_columns = None

# %%
target_source = '../DATA/JSON/PAPAER_SCRAPING.json'
data = []

with open(target_source) as d:
    data = json.load(d)

# %%
len(data)
# Out:
# 2414

# %%
data[0]
# Out:
# {'_id': {'$oid': '6751e8034da435bf323c327b'},
#  'index': 0,
#  'data': {'Eid': '2-s2.0-85029781991',
#   'Year': 2017,
#   'idxterms': ['Concretes',
#    'Fiber reinforced materials',
#    'Fibers',
#    'High performance concrete',
#    'Shear flow',
#    'Experimental program',
#    'Fiber contents',
#    'High performance fiber reinforced concrete',
#    'Main parameters',
#    'Shear capacity',
#    'Shear reinforcement',
#    'Structural behaviors',
#    'Ultimate capacity',
#    'Reinforced concrete'],
#   'authkeyword': ['Fiber content',
#    'High performance fiber reinforced concrete (HPFRC)',
#    'Shear capacity',
#    'Shear reinforcement'],
#   'Funding_Agency': [{'name': 'Ratchadapisek Sompoch Endowment Fund',
#     'link': None},
#    {'name': 'Ministry of Education',
#     'link': 'https://www.fundinginstitutional.com/funders/100009950'},
#    {'name': 'Chulalongkorn University',
#     'link': 'https://www.fundinginstitutional.com/funders/501100002873'}],
#   'Cited_Count': 61,
#   'Document_type': 'Article'}}

# %%
idx_terms_list = []
bucket1 = []
bucket2 = []
valid_data = []

# %%
for i in data:
    if (i['data']['Document_type'][-1] == '•'):
        i['data']['Document_type'] = i['data']['Document_type'][:-1]
    
    if (i['data']['Document_type'] == 'Article'):
        bucket1.append(i)

# %%
len(bucket1)
# Out:
# 1792

# %%
for i in bucket1:
    if (len(i['data']['idxterms']) == 0 or (len(i['data']['idxterms']) != 0 and i['data']['idxterms'][0] != '')):
        bucket2.append(i)

# %%
len(bucket2)
# Out:
# 1717

# %%
for i in bucket2:
    if (len(i['data']['authkeyword']) == 0 or (len(i['data']['authkeyword']) != 0 and i['data']['authkeyword'][0] != '')):
        valid_data.append(i)

# %%
len(valid_data)
# Out:
# 1717

# %%
authkeyword_list = []
idxterms_list = []
agency_list = []
funding_status_cite_list = []

# %%
for i in valid_data:
    eid = i['data']['Eid']
    authkeyword = i['data']['authkeyword']
    idxterms = i['data']['idxterms']
    cite_count = i['data']['Cited_Count']
    funding_agency = i['data']['Funding_Agency']

    for i in authkeyword:
        authkeyword_list.append([eid, i])

    for i in idxterms:
        idxterms_list.append([eid, i])

    for i in funding_agency:
        agency_id = None
        if (i['link'] != None):
            agency_id = i['link'].split('/')[-1]
        if (agency_id != None):
            agency_id = str(agency_id)
        agency_list.append([eid, i['name'], agency_id])

    funding_status_cite_list.append([eid, (0 if len(funding_agency) == 0 else 1), cite_count])

# %%
authkeyword_df = pd.DataFrame(authkeyword_list, columns=['Eid', 'Auth_Keyword']).drop_duplicates().dropna()
authkeyword_df
# Out:
#                      Eid                                       Auth_Keyword
# 0     2-s2.0-85029781991                                      Fiber content
# 1     2-s2.0-85029781991  High performance fiber reinforced concrete (HP...
# 2     2-s2.0-85029781991                                     Shear capacity
# 3     2-s2.0-85029781991                                Shear reinforcement
# 4     2-s2.0-85039703338               Epithelial to mesenchymal transition
# ...                  ...                                                ...
# 6908  2-s2.0-84905892595                        Dynamic cutting force ratio
# 6909  2-s2.0-84905892595                              In-process prediction
# 6910  2-s2.0-84905892595                                Regression analysis
# 6911  2-s2.0-84905892595                                  Surface roughness
# 6912  2-s2.0-84905892595                                   Trapezoidal rule
#
# [6911 rows x 2 columns]

# %%
idxterms_df = pd.DataFrame(idxterms_list, columns=['Eid', 'Index_Terms']).dropna() #ยังไม่ได้ drop duplicate
idxterms_df
# Out:
#                       Eid                   Index_Terms
# 0      2-s2.0-85029781991                     Concretes
# 1      2-s2.0-85029781991    Fiber reinforced materials
# 2      2-s2.0-85029781991                        Fibers
# 3      2-s2.0-85029781991     High performance concrete
# 4      2-s2.0-85029781991                    Shear flow
# ...                   ...                           ...
# 43013  2-s2.0-84905892595                    In-process
# 43014  2-s2.0-84905892595  Multiple regression analysis
# 43015  2-s2.0-84905892595    Surface roughness profiles
# 43016  2-s2.0-84905892595             Trapezoidal rules
# 43017  2-s2.0-84905892595             Surface roughness
#
# [43018 rows x 2 columns]

# %%
funding_status_cite_df = pd.DataFrame(funding_status_cite_list, columns=['Eid', 'Funding_Status', 'Cite-By Count']).drop_duplicates().dropna()
funding_status_cite_df
# Out:
#                      Eid  Funding_Status  Cite-By Count
# 0     2-s2.0-85029781991               1             61
# 1     2-s2.0-85039703338               0             31
# 2     2-s2.0-85039924338               1              4
# 3     2-s2.0-85039922521               1              9
# 4     2-s2.0-85039920890               1              6
# ...                  ...             ...            ...
# 1712  2-s2.0-84964267738               0             26
# 1713  2-s2.0-84922900576               0           1846
# 1714  2-s2.0-84928152781               0             12
# 1715  2-s2.0-84930797064               0              4
# 1716  2-s2.0-84905892595               1             43
#
# [1717 rows x 3 columns]

# %%
agency_list
# Out:
# [['2-s2.0-85029781991', 'Ratchadapisek Sompoch Endowment Fund', None],
#  ['2-s2.0-85029781991', 'Ministry of Education', '100009950'],
#  ['2-s2.0-85029781991', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039924338', 'Ratchadapisek Sompoch Endowment Fund', None],
#  ['2-s2.0-85039924338', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039924338', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85039922521', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039920890', 'National Research University Project', None],
#  ['2-s2.0-85039920890',
#   'Office of the Higher Education Commission',
#   '100012527'],
#  ['2-s2.0-85039920890', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039920812', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039917530', 'CU-ASEAN', None],
#  ['2-s2.0-85039917530', 'Ministry of Education', '100009950'],
#  ['2-s2.0-85039917530', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039914805', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039914805', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85039914338', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039914338', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85039914338', 'Burapha University', '501100006749'],
#  ['2-s2.0-85039898441', 'CU Scholarship', None],
#  ['2-s2.0-85039898441', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039898441', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85039897067',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85039709530', 'HST-AR-12847', None],
#  ['2-s2.0-85039709530',
#   'Thailand Research Fund/Office of the Higher Education Commission',
#   None],
#  ['2-s2.0-85039709530',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85038429957', 'Rachadaphiseksomphot Fund', None],
#  ['2-s2.0-85038429957', 'Russian State Research Project', None],
#  ['2-s2.0-85038429957',
#   'Russian Foundation for Basic Research',
#   '501100002261'],
#  ['2-s2.0-85038429957', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85038429957', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85032489556', 'Fundacion Araucaria', '100016136'],
#  ['2-s2.0-85032271239', 'Science Achievement Scholarship of Thailand', None],
#  ['2-s2.0-85032271239', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85032271239',
#   'School of Aerospace Science and Technology',
#   '501100005321'],
#  ['2-s2.0-85033555515', 'Center for Innovation in Chemistry', None],
#  ['2-s2.0-85033555515', 'Materials Chemistry Research Center', None],
#  ['2-s2.0-85033555515', 'PERCH-CIC', None],
#  ['2-s2.0-85033555515', 'Higher Education Research Promotion', '100007469'],
#  ['2-s2.0-85033555515',
#   'Office of the Higher Education Commission',
#   '100012527'],
#  ['2-s2.0-85033555515', 'Khon Kaen University', '501100004071'],
#  ['2-s2.0-85033555515', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85021181600', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85021181600', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85021181600', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85021181600', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85041048740', "Nationwide Children's Hospital", '100007520'],
#  ['2-s2.0-85038434704', 'Ratchadaphiseksomphot Endowment Fund', None],
#  ['2-s2.0-85038434704', 'Ministry of Science and Technology', '100007225'],
#  ['2-s2.0-85038434704',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85038434704', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85038434704', 'National Nanotechnology Center', '501100007056'],
#  ['2-s2.0-85038434704',
#   'Ministry of Science and Technology of Thailand',
#   '501100007275'],
#  ['2-s2.0-85028376438', 'R.V.', None],
#  ['2-s2.0-85028376438',
#   'College and Graduate School of Arts and Sciences',
#   '100008458'],
#  ['2-s2.0-85028376438', 'Science and Industry Endowment Fund', '100008716'],
#  ['2-s2.0-85028376438', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85028376438', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85028376438', 'Nordic Energy Research', '501100006142'],
#  ['2-s2.0-85040170019',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85040170019',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85040170019',
#   'National Research Foundation of Korea',
#   '501100003725'],
#  ['2-s2.0-85040170019',
#   "King Mongkut's University of Technology Thonburi",
#   '501100004705'],
#  ['2-s2.0-85052976005',
#   'Office of the Royal Development Projects Board',
#   None],
#  ['2-s2.0-85052976005', 'RDPB', None],
#  ['2-s2.0-85052976005', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85032425979', 'National Research University Project', None],
#  ['2-s2.0-85032425979',
#   'Overseas Research Experience Scholarship for Graduate Student',
#   None],
#  ['2-s2.0-85032425979', 'Ratchadaphiseksomphot Endowment Fund', None],
#  ['2-s2.0-85032425979',
#   'Center of Excellence in Regulatory Science and Innovation',
#   '100008935'],
#  ['2-s2.0-85032425979',
#   'Office of the Higher Education Commission',
#   '100012527'],
#  ['2-s2.0-85032425979', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85032425979', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85038597618', 'CNRS/IN2P3', None],
#  ['2-s2.0-85038597618', 'CPAN', None],
#  ['2-s2.0-85038597618', 'ERC IUT', None],
#  ['2-s2.0-85038597618', 'LNS', None],
#  ['2-s2.0-85038597618', 'MESTD', None],
#  ['2-s2.0-85038597618', 'MON', None],
#  ['2-s2.0-85038597618', 'MSES', None],
#  ['2-s2.0-85038597618', 'MSHE', None],
#  ['2-s2.0-85038597618', 'MoER', None],
#  ['2-s2.0-85038597618', 'PCTI', None],
#  ['2-s2.0-85038597618', 'RAEP', None],
#  ['2-s2.0-85038597618', 'STAR', None],
#  ['2-s2.0-85038597618', 'Swiss Funding Agencies', None],
#  ['2-s2.0-85038597618', 'TUBITAK', None],
#  ['2-s2.0-85038597618', 'ThEPCenter', None],
#  ['2-s2.0-85038597618', 'UASLP-FAI', None],
#  ['2-s2.0-85038597618', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85038597618', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85038597618', 'National Institutes of Health', '100000002'],
#  ['2-s2.0-85038597618', 'U.S. Department of Energy', '100000015'],
#  ['2-s2.0-85038597618', 'Hispanics in Philanthropy', '100001169'],
#  ['2-s2.0-85038597618', 'CS Fund', '100001570'],
#  ['2-s2.0-85038597618',
#   'Departamento Administrativo de Ciencia, Tecnología e Innovación (COLCIENCIAS)',
#   '100007637'],
#  ['2-s2.0-85038597618', 'California Earthquake Authority', '100008931'],
#  ['2-s2.0-85038597618', 'Secretaría de Educación Pública', '100010096'],
#  ['2-s2.0-85038597618', 'Türkiye Atom Enerjisi Kurumu', '100010440'],
#  ['2-s2.0-85038597618', 'Louisiana Academy of Sciences', '100011424'],
#  ['2-s2.0-85038597618',
#   'Missouri University of Science and Technology',
#   '100011535'],
#  ['2-s2.0-85038597618', 'CERN', '100012470'],
#  ['2-s2.0-85038597618',
#   'College of Arts and Sciences, University of Nebraska-Lincoln',
#   '100013235'],
#  ['2-s2.0-85038597618', 'Norwegian Sequencing Centre', '100016847'],
#  ['2-s2.0-85038597618',
#   'Institute for the Promotion of Teaching Science and Technology',
#   '100016907'],
#  ['2-s2.0-85038597618', 'Mountain Equipment Co-operative', '501100000090'],
#  ['2-s2.0-85038597618',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85038597618',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85038597618', 'Royal Astronomical Society', '501100000698'],
#  ['2-s2.0-85038597618', 'Ministry of Education - Singapore', '501100001459'],
#  ['2-s2.0-85038597618',
#   'Department of Atomic Energy, Government of India',
#   '501100001502'],
#  ['2-s2.0-85038597618', 'Science Foundation Ireland', '501100001602'],
#  ['2-s2.0-85038597618', 'Helmholtz-Gemeinschaft', '501100001656'],
#  ['2-s2.0-85038597618', 'Deutsche Forschungsgemeinschaft', '501100001659'],
#  ['2-s2.0-85038597618',
#   'Fundação de Amparo à Pesquisa do Estado de São Paulo',
#   '501100001807'],
#  ['2-s2.0-85038597618',
#   'National Natural Science Foundation of China',
#   '501100001809'],
#  ['2-s2.0-85038597618', 'Research Promotion Foundation', '501100001810'],
#  ['2-s2.0-85038597618',
#   'Fundação para a Ciência e a Tecnologia',
#   '501100001871'],
#  ['2-s2.0-85038597618',
#   'Russian Foundation for Basic Research',
#   '501100002261'],
#  ['2-s2.0-85038597618',
#   'Coordenação de Aperfeiçoamento de Pessoal de Nível Superior',
#   '501100002322'],
#  ['2-s2.0-85038597618', 'Academy of Finland', '501100002341'],
#  ['2-s2.0-85038597618',
#   'Bundesministerium für Bildung und Forschung',
#   '501100002347'],
#  ['2-s2.0-85038597618', 'Austrian Science Fund', '501100002428'],
#  ['2-s2.0-85038597618',
#   'Fonds De La Recherche Scientifique - FNRS',
#   '501100002661'],
#  ['2-s2.0-85038597618', 'Fonds Wetenschappelijk Onderzoek', '501100003130'],
#  ['2-s2.0-85038597618',
#   'Consejo Nacional de Ciencia y Tecnología',
#   '501100003141'],
#  ['2-s2.0-85038597618',
#   'Bundesministerium für Wissenschaft, Forschung und Wirtschaft',
#   '501100003413'],
#  ['2-s2.0-85038597618',
#   'General Secretariat for Research and Technology',
#   '501100003448'],
#  ['2-s2.0-85038597618', 'Hungarian Scientific Research Fund', '501100003549'],
#  ['2-s2.0-85038597618',
#   'Conselho Nacional de Desenvolvimento Científico e Tecnológico',
#   '501100003593'],
#  ['2-s2.0-85038597618',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85038597618', 'Ministry of Science and Technology', '501100003711'],
#  ['2-s2.0-85038597618',
#   'National Research Foundation of Korea',
#   '501100003725'],
#  ['2-s2.0-85038597618',
#   'Joint Institute for Nuclear Research',
#   '501100003822'],
#  ['2-s2.0-85038597618',
#   'Instituto Nazionale di Fisica Nucleare',
#   '501100004007'],
#  ['2-s2.0-85038597618',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85038597618',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85038597618',
#   'Secretaría de Educación Superior, Ciencia, Tecnología e Innovación',
#   '501100004299'],
#  ['2-s2.0-85038597618', 'Universiti Malaya', '501100004386'],
#  ['2-s2.0-85038597618',
#   'Fundação Carlos Chagas Filho de Amparo à Pesquisa do Estado do Rio de Janeiro',
#   '501100004586'],
#  ['2-s2.0-85038597618',
#   'Ministry for Business Innovation and Employment',
#   '501100004629'],
#  ['2-s2.0-85038597618',
#   'National Academy of Sciences of Ukraine',
#   '501100004742'],
#  ['2-s2.0-85038597618', 'Ministry of Education and Science', '501100005992'],
#  ['2-s2.0-85038597618',
#   'Institute for Research in Fundamental Sciences',
#   '501100006115'],
#  ['2-s2.0-85038597618',
#   'Benemérita Universidad Autónoma de Puebla',
#   '501100006348'],
#  ['2-s2.0-85038597618',
#   'Secretaría de Estado de Investigación, Desarrollo e Innovación',
#   '501100007136'],
#  ['2-s2.0-85038597618', 'European Regional Development Fund', '501100008530'],
#  ['2-s2.0-85038597618',
#   'State Atomic Energy Corporation ROSATOM',
#   '501100008687'],
#  ['2-s2.0-85038597618',
#   'Centro de Investigación y de Estudios Avanzados del Instituto Politécnico Nacional',
#   '501100008688'],
#  ['2-s2.0-85038597618', 'Pakistan Atomic Energy Commission', '501100008689'],
#  ['2-s2.0-85038597618',
#   'State Fund for Fundamental Research of Ukraine',
#   '501100008690'],
#  ['2-s2.0-85038597618',
#   'Department of Science and Technology, Government of West Bengal',
#   '501100008789'],
#  ['2-s2.0-85028559492', 'Helse-Vest', None],
#  ['2-s2.0-85034449894', 'CPAN', None],
#  ['2-s2.0-85034449894', 'ERC IUT', None],
#  ['2-s2.0-85034449894', 'LNS', None],
#  ['2-s2.0-85034449894', 'MESTD', None],
#  ['2-s2.0-85034449894', 'MON', None],
#  ['2-s2.0-85034449894', 'MSES', None],
#  ['2-s2.0-85034449894', 'MSHE', None],
#  ['2-s2.0-85034449894', 'MoER', None],
#  ['2-s2.0-85034449894', 'PCTI', None],
#  ['2-s2.0-85034449894', 'RAEP', None],
#  ['2-s2.0-85034449894', 'STAR', None],
#  ['2-s2.0-85034449894', 'Swiss Funding Agencies', None],
#  ['2-s2.0-85034449894', 'TUBITAK', None],
#  ['2-s2.0-85034449894', 'UASLP-FAI', None],
#  ['2-s2.0-85034449894', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85034449894', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85034449894', 'National Institutes of Health', '100000002'],
#  ['2-s2.0-85034449894', 'U.S. Department of Energy', '100000015'],
#  ['2-s2.0-85034449894', 'Hispanics in Philanthropy', '100001169'],
#  ['2-s2.0-85034449894',
#   'Departamento Administrativo de Ciencia, Tecnología e Innovación (COLCIENCIAS)',
#   '100007637'],
#  ['2-s2.0-85034449894', 'Secretaría de Educación Pública', '100010096'],
#  ['2-s2.0-85034449894', 'Türkiye Atom Enerjisi Kurumu', '100010440'],
#  ['2-s2.0-85034449894', 'Louisiana Academy of Sciences', '100011424'],
#  ['2-s2.0-85034449894',
#   'Missouri University of Science and Technology',
#   '100011535'],
#  ['2-s2.0-85034449894', 'CERN', '100012470'],
#  ['2-s2.0-85034449894',
#   'Thailand Center of Excellence in Physics',
#   '100012863'],
#  ['2-s2.0-85034449894', 'Cosmetic Surgery Foundation', '100013521'],
#  ['2-s2.0-85034449894',
#   'Institute for the Promotion of Teaching Science and Technology',
#   '100016907'],
#  ['2-s2.0-85034449894',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85034449894',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85034449894',
#   'Department of Science and Technology, Ministry of Science and Technology, India',
#   '501100001409'],
#  ['2-s2.0-85034449894', 'Ministry of Education - Singapore', '501100001459'],
#  ['2-s2.0-85034449894',
#   'Department of Atomic Energy, Government of India',
#   '501100001502'],
#  ['2-s2.0-85034449894', 'Science Foundation Ireland', '501100001602'],
#  ['2-s2.0-85034449894', 'Helmholtz-Gemeinschaft', '501100001656'],
#  ['2-s2.0-85034449894', 'Deutsche Forschungsgemeinschaft', '501100001659'],
#  ['2-s2.0-85034449894',
#   'Fundação de Amparo à Pesquisa do Estado de São Paulo',
#   '501100001807'],
#  ['2-s2.0-85034449894',
#   'National Natural Science Foundation of China',
#   '501100001809'],
#  ['2-s2.0-85034449894', 'Research Promotion Foundation', '501100001810'],
#  ['2-s2.0-85034449894', 'National Science Council', '501100001868'],
#  ['2-s2.0-85034449894',
#   'Fundação para a Ciência e a Tecnologia',
#   '501100001871'],
#  ['2-s2.0-85034449894',
#   'Russian Foundation for Basic Research',
#   '501100002261'],
#  ['2-s2.0-85034449894',
#   'Coordenação de Aperfeiçoamento de Pessoal de Nível Superior',
#   '501100002322'],
#  ['2-s2.0-85034449894', 'Academy of Finland', '501100002341'],
#  ['2-s2.0-85034449894',
#   'Bundesministerium für Bildung und Forschung',
#   '501100002347'],
#  ['2-s2.0-85034449894', 'Chinese Academy of Sciences', '501100002367'],
#  ['2-s2.0-85034449894', 'Austrian Science Fund', '501100002428'],
#  ['2-s2.0-85034449894',
#   'Fonds De La Recherche Scientifique - FNRS',
#   '501100002661'],
#  ['2-s2.0-85034449894', 'Russian Academy of Sciences', '501100002674'],
#  ['2-s2.0-85034449894', 'Fonds Wetenschappelijk Onderzoek', '501100003130'],
#  ['2-s2.0-85034449894',
#   'Consejo Nacional de Ciencia y Tecnología',
#   '501100003141'],
#  ['2-s2.0-85034449894',
#   'Ministerio de Economía y Competitividad',
#   '501100003329'],
#  ['2-s2.0-85034449894',
#   'Bundesministerium für Wissenschaft, Forschung und Wirtschaft',
#   '501100003413'],
#  ['2-s2.0-85034449894',
#   'General Secretariat for Research and Technology',
#   '501100003448'],
#  ['2-s2.0-85034449894',
#   'Ministry of Business, Innovation and Employment',
#   '501100003524'],
#  ['2-s2.0-85034449894', 'Hungarian Scientific Research Fund', '501100003549'],
#  ['2-s2.0-85034449894',
#   'Conselho Nacional de Desenvolvimento Científico e Tecnológico',
#   '501100003593'],
#  ['2-s2.0-85034449894',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85034449894',
#   'National Research Foundation of Korea',
#   '501100003725'],
#  ['2-s2.0-85034449894',
#   'Joint Institute for Nuclear Research',
#   '501100003822'],
#  ['2-s2.0-85034449894',
#   'Instituto Nazionale di Fisica Nucleare',
#   '501100004007'],
#  ['2-s2.0-85034449894',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85034449894',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85034449894',
#   'Secretaría de Educación Superior, Ciencia, Tecnología e Innovación',
#   '501100004299'],
#  ['2-s2.0-85034449894', 'Universiti Malaya', '501100004386'],
#  ['2-s2.0-85034449894',
#   'Fundação Carlos Chagas Filho de Amparo à Pesquisa do Estado do Rio de Janeiro',
#   '501100004586'],
#  ['2-s2.0-85034449894',
#   'Ministry of Science and Technology, Taiwan',
#   '501100004663'],
#  ['2-s2.0-85034449894',
#   'National Academy of Sciences of Ukraine',
#   '501100004742'],
#  ['2-s2.0-85034449894',
#   'Centre National de la Recherche Scientifique',
#   '501100004794'],
#  ['2-s2.0-85034449894', 'Ministry of Education and Science', '501100005992'],
#  ['2-s2.0-85034449894',
#   'Institute for Research in Fundamental Sciences',
#   '501100006115'],
#  ['2-s2.0-85034449894',
#   'Benemérita Universidad Autónoma de Puebla',
#   '501100006348'],
#  ['2-s2.0-85034449894',
#   "Commissariat à l'Énergie Atomique et aux Énergies Alternatives",
#   '501100006489'],
#  ['2-s2.0-85034449894',
#   'Secretaría de Estado de Investigación, Desarrollo e Innovación',
#   '501100007136'],
#  ['2-s2.0-85034449894', 'European Regional Development Fund', '501100008530'],
#  ['2-s2.0-85034449894',
#   'State Atomic Energy Corporation ROSATOM',
#   '501100008687'],
#  ['2-s2.0-85034449894',
#   'Centro de Investigación y de Estudios Avanzados del Instituto Politécnico Nacional',
#   '501100008688'],
#  ['2-s2.0-85034449894', 'Pakistan Atomic Energy Commission', '501100008689'],
#  ['2-s2.0-85034449894',
#   'State Fund for Fundamental Research of Ukraine',
#   '501100008690'],
#  ['2-s2.0-85034449894',
#   'Institut National de Physique Nucléaire et de Physique des Particules',
#   '501100012441'],
#  ['2-s2.0-85057828701', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85034821679', 'CPAN', None],
#  ['2-s2.0-85034821679', 'ERC IUT', None],
#  ['2-s2.0-85034821679', 'EU-ESF', None],
#  ['2-s2.0-85034821679', 'FRIA-Belgium', None],
#  ['2-s2.0-85034821679', 'IWT-Belgium', None],
#  ['2-s2.0-85034821679', 'LNS', None],
#  ['2-s2.0-85034821679', 'MESTD', None],
#  ['2-s2.0-85034821679', 'MON', None],
#  ['2-s2.0-85034821679', 'MSES', None],
#  ['2-s2.0-85034821679', 'MSHE', None],
#  ['2-s2.0-85034821679', 'MoER', None],
#  ['2-s2.0-85034821679', 'PCTI', None],
#  ['2-s2.0-85034821679', 'RAEP', None],
#  ['2-s2.0-85034821679', 'STAR', None],
#  ['2-s2.0-85034821679', 'Swiss Funding Agencies', None],
#  ['2-s2.0-85034821679', 'TUBITAK', None],
#  ['2-s2.0-85034821679', 'UASLP-FAI', None],
#  ['2-s2.0-85034821679', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85034821679', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85034821679', 'National Institutes of Health', '100000002'],
#  ['2-s2.0-85034821679', 'U.S. Department of Energy', '100000015'],
#  ['2-s2.0-85034821679', 'Alfred P. Sloan Foundation', '100000879'],
#  ['2-s2.0-85034821679', 'Welch Foundation', '100000928'],
#  ['2-s2.0-85034821679', 'Welch Foundation', '100000928'],
#  ['2-s2.0-85034821679', 'Hispanics in Philanthropy', '100001169'],
#  ['2-s2.0-85034821679', 'Alexander von Humboldt-Stiftung', '100005156'],
#  ['2-s2.0-85034821679',
#   'Departamento Administrativo de Ciencia, Tecnología e Innovación (COLCIENCIAS)',
#   '100007637'],
#  ['2-s2.0-85034821679', 'Qatar National Research Fund', '100008982'],
#  ['2-s2.0-85034821679', 'Secretaría de Educación Pública', '100010096'],
#  ['2-s2.0-85034821679', 'Türkiye Atom Enerjisi Kurumu', '100010440'],
#  ['2-s2.0-85034821679', 'Horizon 2020 Framework Programme', '100010661'],
#  ['2-s2.0-85034821679', 'Louisiana Academy of Sciences', '100011424'],
#  ['2-s2.0-85034821679',
#   'Missouri University of Science and Technology',
#   '100011535'],
#  ['2-s2.0-85034821679', 'CERN', '100012470'],
#  ['2-s2.0-85034821679',
#   'Thailand Center of Excellence in Physics',
#   '100012863'],
#  ['2-s2.0-85034821679', 'Cosmetic Surgery Foundation', '100013521'],
#  ['2-s2.0-85034821679',
#   'Institute for the Promotion of Teaching Science and Technology',
#   '100016907'],
#  ['2-s2.0-85034821679',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85034821679',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85034821679', 'European Commission', '501100000780'],
#  ['2-s2.0-85034821679', 'European Research Council', '501100000781'],
#  ['2-s2.0-85034821679',
#   'Department of Science and Technology, Ministry of Science and Technology, India',
#   '501100001409'],
#  ['2-s2.0-85034821679',
#   'Council of Scientific and Industrial Research, India',
#   '501100001412'],
#  ['2-s2.0-85034821679', 'Ministry of Education - Singapore', '501100001459'],
#  ['2-s2.0-85034821679',
#   'Department of Atomic Energy, Government of India',
#   '501100001502'],
#  ['2-s2.0-85034821679', 'Science Foundation Ireland', '501100001602'],
#  ['2-s2.0-85034821679', 'Helmholtz-Gemeinschaft', '501100001656'],
#  ['2-s2.0-85034821679', 'Deutsche Forschungsgemeinschaft', '501100001659'],
#  ['2-s2.0-85034821679',
#   'Fundação de Amparo à Pesquisa do Estado de São Paulo',
#   '501100001807'],
#  ['2-s2.0-85034821679',
#   'National Natural Science Foundation of China',
#   '501100001809'],
#  ['2-s2.0-85034821679', 'Research Promotion Foundation', '501100001810'],
#  ['2-s2.0-85034821679',
#   'Ministerstvo Školství, Mládeže a Tělovýchovy',
#   '501100001823'],
#  ['2-s2.0-85034821679', 'National Science Council', '501100001868'],
#  ['2-s2.0-85034821679', 'Fundacja na rzecz Nauki Polskiej', '501100001870'],
#  ['2-s2.0-85034821679',
#   'Fundação para a Ciência e a Tecnologia',
#   '501100001871'],
#  ['2-s2.0-85034821679',
#   'Russian Foundation for Basic Research',
#   '501100002261'],
#  ['2-s2.0-85034821679',
#   'Coordenação de Aperfeiçoamento de Pessoal de Nível Superior',
#   '501100002322'],
#  ['2-s2.0-85034821679', 'Academy of Finland', '501100002341'],
#  ['2-s2.0-85034821679',
#   'Bundesministerium für Bildung und Forschung',
#   '501100002347'],
#  ['2-s2.0-85034821679', 'Chinese Academy of Sciences', '501100002367'],
#  ['2-s2.0-85034821679', 'Austrian Science Fund', '501100002428'],
#  ['2-s2.0-85034821679',
#   'Fonds De La Recherche Scientifique - FNRS',
#   '501100002661'],
#  ['2-s2.0-85034821679', 'Russian Academy of Sciences', '501100002674'],
#  ['2-s2.0-85034821679',
#   'Belgian Federal Science Policy Office',
#   '501100002749'],
#  ['2-s2.0-85034821679', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85034821679', 'Fonds Wetenschappelijk Onderzoek', '501100003130'],
#  ['2-s2.0-85034821679',
#   'Agentschap voor Innovatie door Wetenschap en Technologie',
#   '501100003132'],
#  ['2-s2.0-85034821679',
#   'Fonds pour la Formation à la Recherche dans l’Industrie et dans l’Agriculture',
#   '501100003134'],
#  ['2-s2.0-85034821679',
#   'Consejo Nacional de Ciencia y Tecnología',
#   '501100003141'],
#  ['2-s2.0-85034821679',
#   'Ministerio de Economía y Competitividad',
#   '501100003329'],
#  ['2-s2.0-85034821679',
#   'Bundesministerium für Wissenschaft, Forschung und Wirtschaft',
#   '501100003413'],
#  ['2-s2.0-85034821679',
#   'General Secretariat for Research and Technology',
#   '501100003448'],
#  ['2-s2.0-85034821679',
#   'Ministry of Business, Innovation and Employment',
#   '501100003524'],
#  ['2-s2.0-85034821679', 'Hungarian Scientific Research Fund', '501100003549'],
#  ['2-s2.0-85034821679',
#   'Conselho Nacional de Desenvolvimento Científico e Tecnológico',
#   '501100003593'],
#  ['2-s2.0-85034821679',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85034821679',
#   'National Research Foundation of Korea',
#   '501100003725'],
#  ['2-s2.0-85034821679',
#   'Joint Institute for Nuclear Research',
#   '501100003822'],
#  ['2-s2.0-85034821679',
#   'Instituto Nazionale di Fisica Nucleare',
#   '501100004007'],
#  ['2-s2.0-85034821679', 'A.G. Leventis Foundation', '501100004117'],
#  ['2-s2.0-85034821679',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85034821679',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85034821679', 'Narodowe Centrum Nauki', '501100004281'],
#  ['2-s2.0-85034821679', 'Narodowe Centrum Nauki', '501100004281'],
#  ['2-s2.0-85034821679',
#   'Secretaría de Educación Superior, Ciencia, Tecnología e Innovación',
#   '501100004299'],
#  ['2-s2.0-85034821679', 'Universiti Malaya', '501100004386'],
#  ['2-s2.0-85034821679',
#   'Ministerstwo Nauki i Szkolnictwa Wyższego',
#   '501100004569'],
#  ['2-s2.0-85034821679',
#   'Fundação Carlos Chagas Filho de Amparo à Pesquisa do Estado do Rio de Janeiro',
#   '501100004586'],
#  ['2-s2.0-85034821679',
#   'Ministry of Science and Technology, Taiwan',
#   '501100004663'],
#  ['2-s2.0-85034821679',
#   'National Academy of Sciences of Ukraine',
#   '501100004742'],
#  ['2-s2.0-85034821679',
#   'Centre National de la Recherche Scientifique',
#   '501100004794'],
#  ['2-s2.0-85034821679', 'Ministry of Education and Science', '501100005992'],
#  ['2-s2.0-85034821679',
#   'Institute for Research in Fundamental Sciences',
#   '501100006115'],
#  ['2-s2.0-85034821679',
#   'Benemérita Universidad Autónoma de Puebla',
#   '501100006348'],
#  ['2-s2.0-85034821679',
#   "Commissariat à l'Énergie Atomique et aux Énergies Alternatives",
#   '501100006489'],
#  ['2-s2.0-85034821679',
#   'Secretaría de Estado de Investigación, Desarrollo e Innovación',
#   '501100007136'],
#  ['2-s2.0-85034821679', 'Horizon 2020', '501100007601'],
#  ['2-s2.0-85034821679', 'Horizon 2020', '501100007601'],
#  ['2-s2.0-85034821679', 'European Regional Development Fund', '501100008530'],
#  ['2-s2.0-85034821679',
#   'State Atomic Energy Corporation ROSATOM',
#   '501100008687'],
#  ['2-s2.0-85034821679',
#   'Centro de Investigación y de Estudios Avanzados del Instituto Politécnico Nacional',
#   '501100008688'],
#  ['2-s2.0-85034821679', 'Pakistan Atomic Energy Commission', '501100008689'],
#  ['2-s2.0-85034821679',
#   'State Fund for Fundamental Research of Ukraine',
#   '501100008690'],
#  ['2-s2.0-85034821679',
#   'Institut National de Physique Nucléaire et de Physique des Particules',
#   '501100012441'],
#  ['2-s2.0-85045692442', 'Faculty of Science, Kasetsart University', None],
#  ['2-s2.0-85045692442', 'National Research University', None],
#  ['2-s2.0-85045692442', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85045692442',
#   'Kasetsart University Research and Development Institute',
#   '501100005621'],
#  ['2-s2.0-85045692442',
#   'Graduate School, Kasetsart University',
#   '501100007943'],
#  ['2-s2.0-85045642591', 'Higher Education Research Promotion', '100007469'],
#  ['2-s2.0-85045642591', 'Srinakharinwirot University', '100009570'],
#  ['2-s2.0-85045642591',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85045642591', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85042529228', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85047073019', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85042128472', 'Chulalong-korn University', None],
#  ['2-s2.0-85042128472', 'Rachadapisaek Sompote Fund', None],
#  ['2-s2.0-85042128472', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85042128472',
#   'Graduate School, Kasetsart University',
#   '501100007943'],
#  ['2-s2.0-85041353839', 'Ratchadapiseksompotch Research Fund', None],
#  ['2-s2.0-85041353839', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85041353839',
#   'Faculty of Medicine, Chulalongkorn University',
#   '501100004776'],
#  ['2-s2.0-85041353839',
#   'Faculty of Medicine, Chulalongkorn University',
#   '501100004776'],
#  ['2-s2.0-85038612821', 'CPAN', None],
#  ['2-s2.0-85038612821', 'EU-ESF', None],
#  ['2-s2.0-85038612821', 'MSES', None],
#  ['2-s2.0-85038612821', 'MoER', None],
#  ['2-s2.0-85038612821', 'PCTI', None],
#  ['2-s2.0-85038612821', 'STAR', None],
#  ['2-s2.0-85038612821', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85038612821', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85038612821', 'National Institutes of Health', '100000002'],
#  ['2-s2.0-85038612821', 'U.S. Department of Energy', '100000015'],
#  ['2-s2.0-85038612821', 'Alfred P. Sloan Foundation', '100000879'],
#  ['2-s2.0-85038612821', 'Welch Foundation', '100000928'],
#  ['2-s2.0-85038612821', 'Welch Foundation', '100000928'],
#  ['2-s2.0-85038612821', 'Hispanics in Philanthropy', '100001169'],
#  ['2-s2.0-85038612821', 'Alexander von Humboldt-Stiftung', '100005156'],
#  ['2-s2.0-85038612821',
#   'Departamento Administrativo de Ciencia, Tecnología e Innovación (COLCIENCIAS)',
#   '100007637'],
#  ['2-s2.0-85038612821', 'Qatar National Research Fund', '100008982'],
#  ['2-s2.0-85038612821', 'Ministry of Education and Science', '100009002'],
#  ['2-s2.0-85038612821',
#   'Direktion für Entwicklung und Zusammenarbeit',
#   '100009131'],
#  ['2-s2.0-85038612821', 'Secretaría de Educación Pública', '100010096'],
#  ['2-s2.0-85038612821', 'Türkiye Atom Enerjisi Kurumu', '100010440'],
#  ['2-s2.0-85038612821', 'Horizon 2020 Framework Programme', '100010661'],
#  ['2-s2.0-85038612821', 'Louisiana Academy of Sciences', '100011424'],
#  ['2-s2.0-85038612821', 'CERN', '100012470'],
#  ['2-s2.0-85038612821',
#   'Thailand Center of Excellence in Physics',
#   '100012863'],
#  ['2-s2.0-85038612821', 'Cosmetic Surgery Foundation', '100013521'],
#  ['2-s2.0-85038612821',
#   'Institute for the Promotion of Teaching Science and Technology',
#   '100016907'],
#  ['2-s2.0-85038612821', 'Ministerstwo Obrony Narodowej', '100019880'],
#  ['2-s2.0-85038612821',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85038612821',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85038612821', 'Marie Curie', '501100000654'],
#  ['2-s2.0-85038612821', 'European Commission', '501100000780'],
#  ['2-s2.0-85038612821', 'European Research Council', '501100000781'],
#  ['2-s2.0-85038612821',
#   'Department of Science and Technology, Ministry of Science and Technology, India',
#   '501100001409'],
#  ['2-s2.0-85038612821',
#   'Council of Scientific and Industrial Research, India',
#   '501100001412'],
#  ['2-s2.0-85038612821', 'Ministry of Education - Singapore', '501100001459'],
#  ['2-s2.0-85038612821',
#   'Department of Atomic Energy, Government of India',
#   '501100001502'],
#  ['2-s2.0-85038612821', 'Science Foundation Ireland', '501100001602'],
#  ['2-s2.0-85038612821', 'Helmholtz-Gemeinschaft', '501100001656'],
#  ['2-s2.0-85038612821', 'Deutsche Forschungsgemeinschaft', '501100001659'],
#  ['2-s2.0-85038612821',
#   'Fundação de Amparo à Pesquisa do Estado de São Paulo',
#   '501100001807'],
#  ['2-s2.0-85038612821',
#   'National Natural Science Foundation of China',
#   '501100001809'],
#  ['2-s2.0-85038612821', 'Research Promotion Foundation', '501100001810'],
#  ['2-s2.0-85038612821',
#   'Ministerstvo Školství, Mládeže a Tělovýchovy',
#   '501100001823'],
#  ['2-s2.0-85038612821', 'National Science Council', '501100001868'],
#  ['2-s2.0-85038612821', 'Fundacja na rzecz Nauki Polskiej', '501100001870'],
#  ['2-s2.0-85038612821',
#   'Fundação para a Ciência e a Tecnologia',
#   '501100001871'],
#  ['2-s2.0-85038612821',
#   'Russian Foundation for Basic Research',
#   '501100002261'],
#  ['2-s2.0-85038612821', 'Eesti Teadusagentuur', '501100002301'],
#  ['2-s2.0-85038612821',
#   'Coordenação de Aperfeiçoamento de Pessoal de Nível Superior',
#   '501100002322'],
#  ['2-s2.0-85038612821', 'Academy of Finland', '501100002341'],
#  ['2-s2.0-85038612821',
#   'Bundesministerium für Bildung und Forschung',
#   '501100002347'],
#  ['2-s2.0-85038612821', 'Chinese Academy of Sciences', '501100002367'],
#  ['2-s2.0-85038612821', 'Austrian Science Fund', '501100002428'],
#  ['2-s2.0-85038612821',
#   'Fonds De La Recherche Scientifique - FNRS',
#   '501100002661'],
#  ['2-s2.0-85038612821', 'Russian Academy of Sciences', '501100002674'],
#  ['2-s2.0-85038612821',
#   'Belgian Federal Science Policy Office',
#   '501100002749'],
#  ['2-s2.0-85038612821', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85038612821',
#   'Federación Española de Enfermedades Raras',
#   '501100002924'],
#  ['2-s2.0-85038612821', 'Fonds Wetenschappelijk Onderzoek', '501100003130'],
#  ['2-s2.0-85038612821',
#   'Agentschap voor Innovatie door Wetenschap en Technologie',
#   '501100003132'],
#  ['2-s2.0-85038612821',
#   'Fonds pour la Formation à la Recherche dans l’Industrie et dans l’Agriculture',
#   '501100003134'],
#  ['2-s2.0-85038612821',
#   'Consejo Nacional de Ciencia y Tecnología',
#   '501100003141'],
#  ['2-s2.0-85038612821',
#   'Ministerio de Educación, Cultura y Deporte',
#   '501100003176'],
#  ['2-s2.0-85038612821',
#   'Bundesministerium für Wissenschaft, Forschung und Wirtschaft',
#   '501100003413'],
#  ['2-s2.0-85038612821',
#   'General Secretariat for Research and Technology',
#   '501100003448'],
#  ['2-s2.0-85038612821',
#   'Ministry of Business, Innovation and Employment',
#   '501100003524'],
#  ['2-s2.0-85038612821', 'Hungarian Scientific Research Fund', '501100003549'],
#  ['2-s2.0-85038612821',
#   'Conselho Nacional de Desenvolvimento Científico e Tecnológico',
#   '501100003593'],
#  ['2-s2.0-85038612821',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85038612821',
#   'National Research Foundation of Korea',
#   '501100003725'],
#  ['2-s2.0-85038612821',
#   'Joint Institute for Nuclear Research',
#   '501100003822'],
#  ['2-s2.0-85038612821',
#   'Instituto Nazionale di Fisica Nucleare',
#   '501100004007'],
#  ['2-s2.0-85038612821', 'A.G. Leventis Foundation', '501100004117'],
#  ['2-s2.0-85038612821',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85038612821',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85038612821', 'Narodowe Centrum Nauki', '501100004281'],
#  ['2-s2.0-85038612821', 'Narodowe Centrum Nauki', '501100004281'],
#  ['2-s2.0-85038612821',
#   'Secretaría de Educación Superior, Ciencia, Tecnología e Innovación',
#   '501100004299'],
#  ['2-s2.0-85038612821', 'Universiti Malaya', '501100004386'],
#  ['2-s2.0-85038612821',
#   'Türkiye Bilimsel ve Teknolojik Araştirma Kurumu',
#   '501100004410'],
#  ['2-s2.0-85038612821',
#   'Ministarstvo Prosvete, Nauke i Tehnološkog Razvoja',
#   '501100004564'],
#  ['2-s2.0-85038612821', 'Ministerstwo Edukacji i Nauki', '501100004569'],
#  ['2-s2.0-85038612821',
#   'Fundação Carlos Chagas Filho de Amparo à Pesquisa do Estado do Rio de Janeiro',
#   '501100004586'],
#  ['2-s2.0-85038612821',
#   'Ministry of Science and Technology, Taiwan',
#   '501100004663'],
#  ['2-s2.0-85038612821',
#   'National Academy of Sciences of Ukraine',
#   '501100004742'],
#  ['2-s2.0-85038612821',
#   'Centre National de la Recherche Scientifique',
#   '501100004794'],
#  ['2-s2.0-85038612821',
#   'Universidad Autónoma de San Luis Potosí',
#   '501100005324'],
#  ['2-s2.0-85038612821', 'Ministry of Education and Science', '501100005992'],
#  ['2-s2.0-85038612821',
#   'Institute for Research in Fundamental Sciences',
#   '501100006115'],
#  ['2-s2.0-85038612821',
#   'Benemérita Universidad Autónoma de Puebla',
#   '501100006348'],
#  ['2-s2.0-85038612821',
#   "Commissariat à l'Énergie Atomique et aux Énergies Alternatives",
#   '501100006489'],
#  ['2-s2.0-85038612821',
#   'Secretaría de Estado de Investigación, Desarrollo e Innovación',
#   '501100007136'],
#  ['2-s2.0-85038612821', 'Horizon 2020', '501100007601'],
#  ['2-s2.0-85038612821', 'Horizon 2020', '501100007601'],
#  ['2-s2.0-85038612821', 'European Regional Development Fund', '501100008530'],
#  ['2-s2.0-85038612821',
#   'State Atomic Energy Corporation ROSATOM',
#   '501100008687'],
#  ['2-s2.0-85038612821',
#   'Centro de Investigación y de Estudios Avanzados del Instituto Politécnico Nacional',
#   '501100008688'],
#  ['2-s2.0-85038612821', 'Pakistan Atomic Energy Commission', '501100008689'],
#  ['2-s2.0-85038612821',
#   'State Fund for Fundamental Research of Ukraine',
#   '501100008690'],
#  ['2-s2.0-85038612821',
#   'Institut National de Physique Nucléaire et de Physique des Particules',
#   '501100012441'],
#  ['2-s2.0-85038612821',
#   'Laboratorio Nacional de Supercómputo del Sureste de Mexico',
#   '501100022285'],
#  ['2-s2.0-85040704260', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85040704260', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85044253500',
#   'Agricultural Research Development Agency',
#   '501100005076'],
#  ['2-s2.0-85040722165', 'Silpakorn University', '501100006436'],
#  ['2-s2.0-85040225133', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85040114563', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039172717', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85040064175',
#   'National Research Council of Thailand',
#   '501100004704'],
#  ['2-s2.0-85039172188', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85039151846',
#   'Faculty of Veterinary Science, Chulalongkorn University',
#   None],
#  ['2-s2.0-85039151846', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85049393881',
#   'Agentschap voor Innovatie doorWetenschapenTechnologie',
#   None],
#  ['2-s2.0-85049393881', 'CPAN', None],
#  ['2-s2.0-85049393881', 'ERC IUT', None],
#  ['2-s2.0-85049393881', 'EU-ESF', None],
#  ['2-s2.0-85049393881', 'FRIA-Belgium', None],
#  ['2-s2.0-85049393881', 'IWT-Belgium', None],
#  ['2-s2.0-85049393881', 'LNS', None],
#  ['2-s2.0-85049393881', 'MESTD', None],
#  ['2-s2.0-85049393881', 'MON', None],
#  ['2-s2.0-85049393881', 'MSES', None],
#  ['2-s2.0-85049393881', 'MSHE', None],
#  ['2-s2.0-85049393881', 'MoER', None],
#  ['2-s2.0-85049393881', 'PCTI', None],
#  ['2-s2.0-85049393881', 'RAEP', None],
#  ['2-s2.0-85049393881', 'STAR', None],
#  ['2-s2.0-85049393881', 'Swiss Funding Agencies', None],
#  ['2-s2.0-85049393881', 'TUBITAK', None],
#  ['2-s2.0-85049393881', 'UASLP-FAI', None],
#  ['2-s2.0-85049393881', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85049393881', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85049393881', 'National Institutes of Health', '100000002'],
#  ['2-s2.0-85049393881', 'U.S. Department of Energy', '100000015'],
#  ['2-s2.0-85049393881', 'Alfred P. Sloan Foundation', '100000879'],
#  ['2-s2.0-85049393881', 'Welch Foundation', '100000928'],
#  ['2-s2.0-85049393881', 'Welch Foundation', '100000928'],
#  ['2-s2.0-85049393881', 'Hispanics in Philanthropy', '100001169'],
#  ['2-s2.0-85049393881', 'California Department of Fish and Game', '100004807'],
#  ['2-s2.0-85049393881', 'Alexander von Humboldt-Stiftung', '100005156'],
#  ['2-s2.0-85049393881', 'University of Mississippi', '100006940'],
#  ['2-s2.0-85049393881',
#   'Departamento Administrativo de Ciencia, Tecnología e Innovación (COLCIENCIAS)',
#   '100007637'],
#  ['2-s2.0-85049393881', "Children's Specialists Foundation", '100008182'],
#  ['2-s2.0-85049393881', 'Qatar National Research Fund', '100008982'],
#  ['2-s2.0-85049393881', 'Secretaría de Educación Pública', '100010096'],
#  ['2-s2.0-85049393881', 'Türkiye Atom Enerjisi Kurumu', '100010440'],
#  ['2-s2.0-85049393881', 'Horizon 2020 Framework Programme', '100010661'],
#  ['2-s2.0-85049393881', 'Santa Fe Institute', '100011419'],
#  ['2-s2.0-85049393881', 'Louisiana Academy of Sciences', '100011424'],
#  ['2-s2.0-85049393881',
#   'Missouri University of Science and Technology',
#   '100011535'],
#  ['2-s2.0-85049393881', 'CERN', '100012470'],
#  ['2-s2.0-85049393881',
#   'Thailand Center of Excellence in Physics',
#   '100012863'],
#  ['2-s2.0-85049393881', 'Cosmetic Surgery Foundation', '100013521'],
#  ['2-s2.0-85049393881',
#   'Institute for the Promotion of Teaching Science and Technology',
#   '100016907'],
#  ['2-s2.0-85049393881',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85049393881',
#   'Science and Technology Facilities Council',
#   '501100000271'],
#  ['2-s2.0-85049393881', 'European Commission', '501100000780'],
#  ['2-s2.0-85049393881', 'European Research Council', '501100000781'],
#  ['2-s2.0-85049393881',
#   'Department of Science and Technology, Ministry of Science and Technology, India',
#   '501100001409'],
#  ['2-s2.0-85049393881',
#   'Council of Scientific and Industrial Research, India',
#   '501100001412'],
#  ['2-s2.0-85049393881', 'Ministry of Education - Singapore', '501100001459'],
#  ['2-s2.0-85049393881',
#   'Department of Atomic Energy, Government of India',
#   '501100001502'],
#  ['2-s2.0-85049393881', 'Science Foundation Ireland', '501100001602'],
#  ['2-s2.0-85049393881', 'Helmholtz-Gemeinschaft', '501100001656'],
#  ['2-s2.0-85049393881', 'Deutsche Forschungsgemeinschaft', '501100001659'],
#  ['2-s2.0-85049393881',
#   'Fundação de Amparo à Pesquisa do Estado de São Paulo',
#   '501100001807'],
#  ['2-s2.0-85049393881',
#   'National Natural Science Foundation of China',
#   '501100001809'],
#  ['2-s2.0-85049393881', 'Research Promotion Foundation', '501100001810'],
#  ['2-s2.0-85049393881',
#   'Ministerstvo Školství, Mládeže a Tělovýchovy',
#   '501100001823'],
#  ['2-s2.0-85049393881', 'National Science Council', '501100001868'],
#  ['2-s2.0-85049393881', 'Fundacja na rzecz Nauki Polskiej', '501100001870'],
#  ['2-s2.0-85049393881',
#   'Fundação para a Ciência e a Tecnologia',
#   '501100001871'],
#  ['2-s2.0-85049393881',
#   'Russian Foundation for Basic Research',
#   '501100002261'],
#  ['2-s2.0-85049393881',
#   'Coordenação de Aperfeiçoamento de Pessoal de Nível Superior',
#   '501100002322'],
#  ['2-s2.0-85049393881', 'Suomen Akatemia', '501100002341'],
#  ['2-s2.0-85049393881',
#   'Bundesministerium für Bildung und Forschung',
#   '501100002347'],
#  ['2-s2.0-85049393881', 'Chinese Academy of Sciences', '501100002367'],
#  ['2-s2.0-85049393881', 'Austrian Science Fund', '501100002428'],
#  ['2-s2.0-85049393881',
#   'Fonds De La Recherche Scientifique - FNRS',
#   '501100002661'],
#  ['2-s2.0-85049393881', 'Russian Academy of Sciences', '501100002674'],
#  ['2-s2.0-85049393881',
#   'Belgian Federal Science Policy Office',
#   '501100002749'],
#  ['2-s2.0-85049393881', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85049393881',
#   'Federación Española de Enfermedades Raras',
#   '501100002924'],
#  ['2-s2.0-85049393881', 'Ministry of Education, Ethiopia', '501100003081'],
#  ['2-s2.0-85049393881', 'Fonds Wetenschappelijk Onderzoek', '501100003130'],
#  ['2-s2.0-85049393881',
#   'Fonds pour la Formation à la Recherche dans l’Industrie et dans l’Agriculture',
#   '501100003134'],
#  ['2-s2.0-85049393881',
#   'Consejo Nacional de Ciencia y Tecnología',
#   '501100003141'],
#  ['2-s2.0-85049393881',
#   'Ministerio de Economía y Competitividad',
#   '501100003329'],
#  ['2-s2.0-85049393881',
#   'Bundesministerium für Wissenschaft, Forschung und Wirtschaft',
#   '501100003413'],
#  ['2-s2.0-85049393881',
#   'General Secretariat for Research and Technology',
#   '501100003448'],
#  ['2-s2.0-85049393881',
#   'Ministry of Business, Innovation and Employment',
#   '501100003524'],
#  ['2-s2.0-85049393881', 'Hungarian Scientific Research Fund', '501100003549'],
#  ['2-s2.0-85049393881',
#   'Conselho Nacional de Desenvolvimento Científico e Tecnológico',
#   '501100003593'],
#  ['2-s2.0-85049393881',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85049393881',
#   'National Research Foundation of Korea',
#   '501100003725'],
#  ['2-s2.0-85049393881',
#   'Joint Institute for Nuclear Research',
#   '501100003822'],
#  ['2-s2.0-85049393881',
#   'Instituto Nazionale di Fisica Nucleare',
#   '501100004007'],
#  ['2-s2.0-85049393881', 'A.G. Leventis Foundation', '501100004117'],
#  ['2-s2.0-85049393881', 'Instituto Politécnico de Macau', '501100004152'],
#  ['2-s2.0-85049393881', 'Norsk Sykepleierforbund', '501100004190'],
#  ['2-s2.0-85049393881',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85049393881',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85049393881', 'Narodowe Centrum Nauki', '501100004281'],
#  ['2-s2.0-85049393881', 'Narodowe Centrum Nauki', '501100004281'],
#  ['2-s2.0-85049393881',
#   'Secretaría de Educación Superior, Ciencia, Tecnología e Innovación',
#   '501100004299'],
#  ['2-s2.0-85049393881', 'Universiti Malaya', '501100004386'],
#  ['2-s2.0-85049393881',
#   'Ministerstwo Nauki i Szkolnictwa Wyższego',
#   '501100004569'],
#  ['2-s2.0-85049393881',
#   'Fundação Carlos Chagas Filho de Amparo à Pesquisa do Estado do Rio de Janeiro',
#   '501100004586'],
#  ['2-s2.0-85049393881',
#   'Ministry of Science and Technology, Taiwan',
#   '501100004663'],
#  ['2-s2.0-85049393881',
#   'National Academy of Sciences of Ukraine',
#   '501100004742'],
#  ['2-s2.0-85049393881',
#   'Centre National de la Recherche Scientifique',
#   '501100004794'],
#  ['2-s2.0-85049393881', 'Ministry of Education and Science', '501100005992'],
#  ['2-s2.0-85049393881',
#   'Institute for Research in Fundamental Sciences',
#   '501100006115'],
#  ['2-s2.0-85049393881',
#   'Foundation for Promotion of Material Science and Technology of Japan',
#   '501100006134'],
#  ['2-s2.0-85049393881',
#   'Benemérita Universidad Autónoma de Puebla',
#   '501100006348'],
#  ['2-s2.0-85049393881', 'Ministério da Educação', '501100006366'],
#  ['2-s2.0-85049393881',
#   "Commissariat à l'Énergie Atomique et aux Énergies Alternatives",
#   '501100006489'],
#  ['2-s2.0-85049393881',
#   'Bundesministerium für Bildung und Frauen',
#   '501100006603'],
#  ['2-s2.0-85049393881',
#   'Secretaría de Estado de Investigación, Desarrollo e Innovación',
#   '501100007136'],
#  ['2-s2.0-85049393881', 'Horizon 2020', '501100007601'],
#  ['2-s2.0-85049393881', 'Horizon 2020', '501100007601'],
#  ['2-s2.0-85049393881', 'European Regional Development Fund', '501100008530'],
#  ['2-s2.0-85049393881',
#   'State Atomic Energy Corporation ROSATOM',
#   '501100008687'],
#  ['2-s2.0-85049393881',
#   'Centro de Investigación y de Estudios Avanzados del Instituto Politécnico Nacional',
#   '501100008688'],
#  ['2-s2.0-85049393881', 'Pakistan Atomic Energy Commission', '501100008689'],
#  ['2-s2.0-85049393881',
#   'State Fund for Fundamental Research of Ukraine',
#   '501100008690'],
#  ['2-s2.0-85049393881',
#   'Department of Science and Technology, Government of West Bengal',
#   '501100008789'],
#  ['2-s2.0-85049393881', 'Fundació Catalana de Trasplantament', '501100009091'],
#  ['2-s2.0-85049393881',
#   'Institut National de Physique Nucléaire et de Physique des Particules',
#   '501100012441'],
#  ['2-s2.0-85049393881', 'ofEducation', None],
#  ['2-s2.0-85039151515', 'Faculty of Veterinary Science', None],
#  ['2-s2.0-85042125746', 'COL-CIENCIAS', None],
#  ['2-s2.0-85042125746', 'CPAN', None],
#  ['2-s2.0-85042125746', 'ERC IUT', None],
#  ['2-s2.0-85042125746', 'EU-ESF', None],
#  ['2-s2.0-85042125746', 'FRIA-Belgium', None],
#  ['2-s2.0-85042125746', 'IWT-Belgium', None],
#  ['2-s2.0-85042125746', 'LNS', None],
#  ['2-s2.0-85042125746', 'MESTD', None],
#  ['2-s2.0-85042125746', 'MON', None],
#  ['2-s2.0-85042125746', 'MSES', None],
#  ['2-s2.0-85042125746', 'MSHE', None],
#  ['2-s2.0-85042125746', 'MoER', None],
#  ['2-s2.0-85042125746', 'PCTI', None],
#  ['2-s2.0-85042125746', 'RAEP', None],
#  ['2-s2.0-85042125746', 'STAR', None],
#  ['2-s2.0-85042125746', 'Swiss Funding Agencies', None],
#  ['2-s2.0-85042125746', 'TUBITAK', None],
#  ['2-s2.0-85042125746', 'UASLP-FAI', None],
#  ['2-s2.0-85042125746', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85042125746', 'National Science Foundation', '100000001'],
#  ['2-s2.0-85042125746', 'National Institutes of Health', '100000002'],
#  ['2-s2.0-85042125746', 'U.S. Department of Energy', '100000015'],
#  ['2-s2.0-85042125746', 'Alfred P. Sloan Foundation', '100000879'],
#  ['2-s2.0-85042125746', 'Welch Foundation', '100000928'],
#  ['2-s2.0-85042125746', 'Welch Foundation', '100000928'],
#  ['2-s2.0-85042125746', 'Hispanics in Philanthropy', '100001169'],
#  ['2-s2.0-85042125746', 'Alexander von Humboldt-Stiftung', '100005156'],
#  ['2-s2.0-85042125746', 'Qatar National Research Fund', '100008982'],
#  ['2-s2.0-85042125746', 'Secretaría de Educación Pública', '100010096'],
#  ['2-s2.0-85042125746', 'Türkiye Atom Enerjisi Kurumu', '100010440'],
#  ['2-s2.0-85042125746', 'Horizon 2020 Framework Programme', '100010661'],
#  ['2-s2.0-85042125746', 'Louisiana Academy of Sciences', '100011424'],
#  ['2-s2.0-85042125746',
#   'Missouri University of Science and Technology',
#   '100011535'],
#  ['2-s2.0-85042125746', 'CERN', '100012470'],
#  ['2-s2.0-85042125746',
#   'Thailand Center of Excellence in Physics',
#   '100012863'],
#  ['2-s2.0-85042125746', 'Cosmetic Surgery Foundation', '100013521'],
#  ['2-s2.0-85042125746',
#   'Institute for the Promotion of Teaching Science and Technology',
#   '100016907'],
#  ['2-s2.0-85042125746',
# ...
#   '501100001502'],
#  ['2-s2.0-85037815234', 'Science Foundation Ireland', '501100001602'],
#  ['2-s2.0-85037815234', 'Helmholtz-Gemeinschaft', '501100001656'],
#  ['2-s2.0-85037815234', 'Deutsche Forschungsgemeinschaft', '501100001659'],
#  ['2-s2.0-85037815234',
#   'Fundação de Amparo à Pesquisa do Estado de São Paulo',
#   '501100001807'],
#  ['2-s2.0-85037815234',
#   'National Natural Science Foundation of China',
#   '501100001809'],
#  ['2-s2.0-85037815234', 'Research Promotion Foundation', '501100001810'],
#  ['2-s2.0-85037815234',
#   'Fundação para a Ciência e a Tecnologia',
#   '501100001871'],
#  ['2-s2.0-85037815234',
#   'Russian Foundation for Basic Research',
#   '501100002261'],
#  ['2-s2.0-85037815234',
#   'Coordenação de Aperfeiçoamento de Pessoal de Nível Superior',
#   '501100002322'],
#  ['2-s2.0-85037815234', 'Academy of Finland', '501100002341'],
#  ['2-s2.0-85037815234',
#   'Bundesministerium für Bildung und Forschung',
#   '501100002347'],
#  ['2-s2.0-85037815234', 'Chinese Academy of Sciences', '501100002367'],
#  ['2-s2.0-85037815234', 'Austrian Science Fund', '501100002428'],
#  ['2-s2.0-85037815234',
#   'Fonds De La Recherche Scientifique - FNRS',
#   '501100002661'],
#  ['2-s2.0-85037815234', 'Ministry of Education, Ethiopia', '501100003081'],
#  ['2-s2.0-85037815234', 'Fonds Wetenschappelijk Onderzoek', '501100003130'],
#  ['2-s2.0-85037815234',
#   'Consejo Nacional de Ciencia y Tecnología',
#   '501100003141'],
#  ['2-s2.0-85037815234',
#   'Bundesministerium für Wissenschaft, Forschung und Wirtschaft',
#   '501100003413'],
#  ['2-s2.0-85037815234',
#   'General Secretariat for Research and Technology',
#   '501100003448'],
#  ['2-s2.0-85037815234',
#   'Országos Tudományos Kutatási Alapprogramok',
#   '501100003549'],
#  ['2-s2.0-85037815234',
#   'Conselho Nacional de Desenvolvimento Científico e Tecnológico',
#   '501100003593'],
#  ['2-s2.0-85037815234',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85037815234', 'Ministry of Science and Technology', '501100003711'],
#  ['2-s2.0-85037815234',
#   'National Research Foundation of Korea',
#   '501100003725'],
#  ['2-s2.0-85037815234',
#   'Joint Institute for Nuclear Research',
#   '501100003822'],
#  ['2-s2.0-85037815234',
#   'Instituto Nazionale di Fisica Nucleare',
#   '501100004007'],
#  ['2-s2.0-85037815234', 'Instituto Politécnico de Macau', '501100004152'],
#  ['2-s2.0-85037815234', 'Norsk Sykepleierforbund', '501100004190'],
#  ['2-s2.0-85037815234',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85037815234',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85037815234',
#   'Secretaría de Educación Superior, Ciencia, Tecnología e Innovación',
#   '501100004299'],
#  ['2-s2.0-85037815234', 'Universiti Malaya', '501100004386'],
#  ['2-s2.0-85037815234',
#   'Fundação Carlos Chagas Filho de Amparo à Pesquisa do Estado do Rio de Janeiro',
#   '501100004586'],
#  ['2-s2.0-85037815234',
#   'Ministry for Business Innovation and Employment',
#   '501100004629'],
#  ['2-s2.0-85037815234',
#   'National Academy of Sciences of Ukraine',
#   '501100004742'],
#  ['2-s2.0-85037815234', 'Ministry of Education and Science', '501100005992'],
#  ['2-s2.0-85037815234',
#   'Institute for Research in Fundamental Sciences',
#   '501100006115'],
#  ['2-s2.0-85037815234',
#   'Foundation for Promotion of Material Science and Technology of Japan',
#   '501100006134'],
#  ['2-s2.0-85037815234',
#   'Benemérita Universidad Autónoma de Puebla',
#   '501100006348'],
#  ['2-s2.0-85037815234', 'Ministério da Educação', '501100006366'],
#  ['2-s2.0-85037815234',
#   "Commissariat à l'Énergie Atomique et aux Énergies Alternatives",
#   '501100006489'],
#  ['2-s2.0-85037815234',
#   'Bundesministerium für Bildung und Frauen',
#   '501100006603'],
#  ['2-s2.0-85037815234',
#   'Secretaría de Estado de Investigación, Desarrollo e Innovación',
#   '501100007136'],
#  ['2-s2.0-85037815234', 'European Regional Development Fund', '501100008530'],
#  ['2-s2.0-85037815234',
#   'State Atomic Energy Corporation ROSATOM',
#   '501100008687'],
#  ['2-s2.0-85037815234',
#   'Centro de Investigación y de Estudios Avanzados del Instituto Politécnico Nacional',
#   '501100008688'],
#  ['2-s2.0-85037815234', 'Pakistan Atomic Energy Commission', '501100008689'],
#  ['2-s2.0-85037815234',
#   'State Fund for Fundamental Research of Ukraine',
#   '501100008690'],
#  ['2-s2.0-85037815234',
#   'Department of Science and Technology, Government of West Bengal',
#   '501100008789'],
#  ['2-s2.0-85032809262',
#   'Higher Education Research Promotion National Research Universities Programme',
#   None],
#  ['2-s2.0-85032809262', 'Ratchadapisek Sompoch Endowment Fund', None],
#  ['2-s2.0-85032809262',
#   'Office of the Higher Education Commission',
#   '100012527'],
#  ['2-s2.0-85032809262', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85032829181', 'Chulalong-korn University Scholarship', None],
#  ['2-s2.0-85032829181', 'RGJ Thailand Research Fund', None],
#  ['2-s2.0-85032829181',
#   'Thailand Research Fund-Chinese Academy of Science',
#   None],
#  ['2-s2.0-85032829181',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85032829181',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85032829181', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85032829181', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85032829181', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85032829181', "A'Sharqiyah University", '501100009165'],
#  ['2-s2.0-85032829181', "A'Sharqiyah University", '501100009165'],
#  ['2-s2.0-85031791462', 'Thammasat University Research Fund', None],
#  ['2-s2.0-85031791462', 'Thammasat University', '501100005790'],
#  ['2-s2.0-85031501650', 'Ratchadapiseksompoch Endowment Fund', None],
#  ['2-s2.0-85031501650', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85032985724', 'International Network for Lupus Research', None],
#  ['2-s2.0-85032985724', 'Ratchadaphiseksomphot Endowment Fund', None],
#  ['2-s2.0-85032985724', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85032985724', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85032985724',
#   'National Research Council of Thailand',
#   '501100004704'],
#  ['2-s2.0-85032897320',
#   'Basic Science Program National Research Foundation of Korea',
#   None],
#  ['2-s2.0-85032897320',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85032897320',
#   'Ministry of Science, ICT and Future Planning',
#   '501100003621'],
#  ['2-s2.0-85032897320',
#   'Yonsei University College of Medicine',
#   '501100008005'],
#  ['2-s2.0-85032897320',
#   'Yonsei University College of Medicine',
#   '501100008005'],
#  ['2-s2.0-85031321875', 'Special Task Force for Activating Research', None],
#  ['2-s2.0-85031321875', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85031103516', 'Chiang Mai University', '501100002842'],
#  ['2-s2.0-85031103516', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85031103516', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85031103516', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85032472545',
#   'Canon Foundation for Scientific Research',
#   '100009851'],
#  ['2-s2.0-85032472545',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85032472545',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85032472545',
#   'Ministry of Education, Culture, Sports, Science and Technology',
#   '501100001700'],
#  ['2-s2.0-85032472545',
#   'Ministry of Education, Culture, Sports, Science and Technology',
#   '501100001700'],
#  ['2-s2.0-85032472545', 'Japan Science and Technology Agency', '501100002241'],
#  ['2-s2.0-85032472545',
#   'Core Research for Evolutional Science and Technology',
#   '501100003382'],
#  ['2-s2.0-85030714759', 'Task Force for Activating Research', None],
#  ['2-s2.0-85030714759', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85031920806',
#   'Ratchadapiseksompotch Endowment Fund Part of the',
#   None],
#  ['2-s2.0-85031920806', 'P.E.F. Israel Endowment Funds', '100001284'],
#  ['2-s2.0-85031920806', 'P.E.F. Israel Endowment Funds', '100001284'],
#  ['2-s2.0-85031920806', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85031920806',
#   'National Research Council of Thailand',
#   '501100004704'],
#  ['2-s2.0-85031920806', 'Health Systems Research Institute', '501100010724'],
#  ['2-s2.0-85030473409', 'Ratchadapisek Sompoch Endowment Fund', None],
#  ['2-s2.0-85030473409', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85030473409', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85030234645', 'Special Task Force for Activating Research', None],
#  ['2-s2.0-85030234645', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85029673618', 'Special Task Force for Activating Research', None],
#  ['2-s2.0-85029673618', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85030563516',
#   'Office of the Higher Education Commission',
#   '100012527'],
#  ['2-s2.0-85030563516', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85030563516', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85030563516', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85030563516',
#   'Faculty of Medicine, Chulalongkorn University',
#   '501100004776'],
#  ['2-s2.0-85030563516',
#   'Faculty of Medicine, Chulalongkorn University',
#   '501100004776'],
#  ['2-s2.0-85030718693', 'Aquaculture Technology for Food Security', None],
#  ['2-s2.0-85030718693', 'JST-JICA', None],
#  ['2-s2.0-85030718693', 'Ratchadaphiseksomphot Endowment Fund', None],
#  ['2-s2.0-85030718693', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85030718693', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85030718693',
#   'Science and Technology Research Partnership for Sustainable Development',
#   '501100009037'],
#  ['2-s2.0-85029208129', 'Jadavpur University', '100009589'],
#  ['2-s2.0-85029208129', 'University Grants Committee', '501100001839'],
#  ['2-s2.0-85029569713', 'Chulalongkorn Comprehensive Epilepsy Program', None],
#  ['2-s2.0-85029569713',
#   'Faculty of Medicine, Chulalongkorn University',
#   '501100004776'],
#  ['2-s2.0-85029765631',
#   'National Institute of Allergy and Infectious Diseases',
#   '100000060'],
#  ['2-s2.0-85029765631',
#   'National Institute of Allergy and Infectious Diseases',
#   '100000060'],
#  ['2-s2.0-85029008946',
#   "King Mongkut's University of Technology North Bangkok",
#   '501100007345'],
#  ['2-s2.0-85029406786', 'Center of Excellence in Clinical Virology', None],
#  ['2-s2.0-85029406786', 'Chulalongkorn University and Hospital', None],
#  ['2-s2.0-85029406786', 'Ratchadapiseksomphot Endowment Fund', None],
#  ['2-s2.0-85029406786',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85029406786',
#   'Faculty of Medicine, Chulalongkorn University',
#   '501100004776'],
#  ['2-s2.0-85027694743', 'Thailand’ Pollution Control Department', None],
#  ['2-s2.0-85027694743', 'Australian National University', '501100000995'],
#  ['2-s2.0-85027694743', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85028911471',
#   'Office of the Higher Education Commission',
#   '100012527'],
#  ['2-s2.0-85028911471',
#   'Office of the Higher Education Commission',
#   '100012527'],
#  ['2-s2.0-85028911471', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85028911471', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85028746772', 'National Institutes of Health', '100000002'],
#  ['2-s2.0-85028746772',
#   'National Heart, Lung, and Blood Institute',
#   '100000050'],
#  ['2-s2.0-85028746772', 'National Cancer Institute', '100000054'],
#  ['2-s2.0-85027170300', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85027170300', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85027170300',
#   'National Research Council of Thailand',
#   '501100004704'],
#  ['2-s2.0-85028639282', 'Faculty of Dentistry Research Fund', None],
#  ['2-s2.0-85028639282', 'Ratchadapisek Sompoch Endowment Fund', None],
#  ['2-s2.0-85028639282', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85028639282',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85028617867',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85028617867',
#   'Ministry of Education, Culture, Sports, Science and Technology',
#   '501100001700'],
#  ['2-s2.0-85028617867', 'China Scholarship Council', '501100004543'],
#  ['2-s2.0-85028617867', 'China Scholarship Council', '501100004543'],
#  ['2-s2.0-85026659396',
#   'Japan Society for the Promotion of Science',
#   '501100001691'],
#  ['2-s2.0-85026242667', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85026242667',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85026242667',
#   'National Science and Technology Development Agency',
#   '501100004192'],
#  ['2-s2.0-85026242667', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85026242667', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85026242667',
#   'National Center for Genetic Engineering and Biotechnology',
#   '501100011057'],
#  ['2-s2.0-85026242667',
#   'National Center for Genetic Engineering and Biotechnology',
#   '501100011057'],
#  ['2-s2.0-85025595727', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85025595727', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85027152700', '111 of the State Bureau of Foreign Experts', None],
#  ['2-s2.0-85027152700', 'National Institutes of Health', '100000002'],
#  ['2-s2.0-85027152700',
#   'National Institute of Allergy and Infectious Diseases',
#   '100000060'],
#  ['2-s2.0-85027152700',
#   'Division of Intramural Research, National Institute of Allergy and Infectious Diseases',
#   '100006492'],
#  ['2-s2.0-85027152700',
#   'National Natural Science Foundation of China',
#   '501100001809'],
#  ['2-s2.0-85027152700',
#   "Ministry of Education of the People's Republic of China",
#   '501100002338'],
#  ['2-s2.0-85027152700',
#   'Fundamental Research Funds for the Central Universities',
#   '501100012226'],
#  ['2-s2.0-85022066491', 'Ratchadaphiseksomphot Endowment Fund', None],
#  ['2-s2.0-85022066491', 'Thai Edible Oil Co., Ltd.', None],
#  ['2-s2.0-85022066491', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85026426421', '90th Year Chulalongkorn Scholarship', None],
#  ['2-s2.0-85026426421', 'TRF Senior Research Scholar', None],
#  ['2-s2.0-85026426421', 'Chulalongkorn University', '501100002873'],
#  ['2-s2.0-85026426421', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85026426421',
#   'Faculty of Medicine, Chulalongkorn University',
#   '501100004776'],
#  ['2-s2.0-85019771197', 'National Multiple Sclerosis Society', '100000890'],
#  ['2-s2.0-85019771197', 'National Multiple Sclerosis Society', '100000890'],
#  ['2-s2.0-85020398553', 'BMKG', None],
#  ['2-s2.0-85020398553',
#   'Department of Marine Science, Faculty of Science, Chulalongkorn University, Bangkok, Thailand e School of Environment and Natural Resource Sciences',
#   None],
#  ['2-s2.0-85020398553', 'Faculty of Science and Technology', None],
#  ['2-s2.0-85020398553',
#   'Ramkhamhaeng University, Bangkok, Thailand g Center for Research and Development, Agency for Meteorology, Climatology and Geophysics',
#   None],
#  ['2-s2.0-85020398553', 'VNU University of Science', None],
#  ['2-s2.0-85020398553', 'Vietnam National University', None],
#  ['2-s2.0-85020398553',
#   'Asia-Pacific Network for Global Change Research',
#   '100005536'],
#  ['2-s2.0-85020398553',
#   'Asia-Pacific Network for Global Change Research',
#   '100005536'],
#  ['2-s2.0-85020398553', 'City, University of London', '100007566'],
#  ['2-s2.0-85020398553',
#   'Department of Energy and Climate Change',
#   '100008428'],
#  ['2-s2.0-85020398553',
#   'Vietnam Academy of Science and Technology',
#   '100012046'],
#  ['2-s2.0-85020398553', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85020398553', 'Thailand Research Fund', '501100004396'],
#  ['2-s2.0-85020398553', 'Universiti Kebangsaan Malaysia', '501100004515'],
#  ['2-s2.0-85020398553', 'Universiti Kebangsaan Malaysia', '501100004515'],
#  ['2-s2.0-85020398553',
#   'African University of Science and Technology',
#   '501100005749'],
#  ...]

# %%
agency_df = pd.DataFrame(agency_list, columns=['Eid', 'Agency_Name', 'Agency_ID'])
agency_df
# Out:
#                      Eid                                        Agency_Name  \
# 0     2-s2.0-85029781991               Ratchadapisek Sompoch Endowment Fund
# 1     2-s2.0-85029781991                              Ministry of Education
# 2     2-s2.0-85029781991                           Chulalongkorn University
# 3     2-s2.0-85039924338               Ratchadapisek Sompoch Endowment Fund
# 4     2-s2.0-85039924338                           Chulalongkorn University
# ...                  ...                                                ...
# 8084  2-s2.0-84979256587  International Center for Green Biotechnology o...
# 8085  2-s2.0-84979256587         Japan Society for the Promotion of Science
# 8086  2-s2.0-84979256587  Ministry of Education, Culture, Sports, Scienc...
# 8087  2-s2.0-84929649705                           Chulalongkorn University
# 8088  2-s2.0-84905892595    Office of National Research Council of Thailand
#
#          Agency_ID
# 0             None
# 1        100009950
# 2     501100002873
# 3             None
# 4     501100002873
# ...            ...
# 8084          None
# 8085  501100001691
# 8086  501100001700
# 8087  501100002873
# 8088          None
#
# [8089 rows x 3 columns]

# %%
agency_country_data = pd.read_csv('../DATA/agency_data.csv').drop(columns='Unnamed: 0')
agency_country_data = agency_country_data.rename(columns={'Agency_Name' : 'Agency_Name_From_Data'})
agency_country_data['Agency_ID'] = agency_country_data['Agency_ID'].apply(lambda x : str(x))

# %%
agency_df = agency_df.merge(agency_country_data, how='left', on='Agency_ID')
agency_df = agency_df.drop(columns='Agency_Name_From_Data')

agency_df
# Out:
#                      Eid                                        Agency_Name  \
# 0     2-s2.0-85029781991               Ratchadapisek Sompoch Endowment Fund
# 1     2-s2.0-85029781991                              Ministry of Education
# 2     2-s2.0-85029781991                           Chulalongkorn University
# 3     2-s2.0-85039924338               Ratchadapisek Sompoch Endowment Fund
# 4     2-s2.0-85039924338                           Chulalongkorn University
# ...                  ...                                                ...
# 8084  2-s2.0-84979256587  International Center for Green Biotechnology o...
# 8085  2-s2.0-84979256587         Japan Society for the Promotion of Science
# 8086  2-s2.0-84979256587  Ministry of Education, Culture, Sports, Scienc...
# 8087  2-s2.0-84929649705                           Chulalongkorn University
# 8088  2-s2.0-84905892595    Office of National Research Council of Thailand
#
#          Agency_ID Agency_Country
# 0             None            NaN
# 1        100009950       Thailand
# 2     501100002873       Thailand
# 3             None            NaN
# 4     501100002873       Thailand
# ...            ...            ...
# 8084          None            NaN
# 8085  501100001691          Japan
# 8086  501100001700          Japan
# 8087  501100002873       Thailand
# 8088          None            NaN
#
# [8089 rows x 4 columns]

# %%
agency_df[agency_df['Agency_ID'].isna()]['Agency_Name'].drop_duplicates().to_csv('funding_name_list_scrape.csv', index=False)
