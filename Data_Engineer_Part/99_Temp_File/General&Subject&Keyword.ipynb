# %%
import numpy as np
import pandas as pd
import json

from pathlib import Path

# %%
data = []

# %%
with open('./DATA/JSON/all_data.json') as d:
    data = json.load(d)
    
rows = []
subj = []
keywords = []
affiliations = []
funds = []

for record in data:
    try:
        title = record['abstracts-retrieval-response']['coredata']['dc:title']
        publish_year = record['abstracts-retrieval-response']['item']['ait:process-info']['ait:date-sort']['@year']
        eid = record['abstracts-retrieval-response']['coredata']['eid']
        aggregation_type = record['abstracts-retrieval-response']['coredata']['prism:aggregationType']
        authors = record['abstracts-retrieval-response']['authors']['author']
        author_count = len(authors)
        if record['abstracts-retrieval-response']['language']:
            language = record['abstracts-retrieval-response']['language']['@xml:lang']
        else: language = None
        
        rows.append({
            'Title': title,
            'Publish_year': publish_year,
            'Eid': eid,
            'Aggregation_type': aggregation_type,
            'Author_Count': author_count,
            'Language' : language
        })
        if "subject-areas" in record['abstracts-retrieval-response']:
            areas = record['abstracts-retrieval-response']['subject-areas']['subject-area']
            for area in areas:
                subj.append({
                    'Eid': eid,
                    'Subject_Area': area["$"] if "$" in area else None,
                    'Subject_Code': area["@code"] if "@code" in area else None,
                })
        
        if "author-keywords" in record['abstracts-retrieval-response']['item']['bibrecord']['head']['citation-info']:
            keyword = record['abstracts-retrieval-response']['item']['bibrecord']['head']['citation-info']['author-keywords']['author-keyword']
            for key in keyword:
                keywords.append({
                    'Eid':eid,
                    'Keyword': key["$"] if "$" in key else None,
                    'Language':key["@xml:lang"] if "@xml:lang" in key else None,
                    'Original':key["@original"] if "@original" in key else None
                })
            
        if "affiliation" in record['abstracts-retrieval-response']:
            affils = record['abstracts-retrieval-response']['affiliation']
            for affil in affils:
                affiliations.append({
                    'Eid': eid,
                    'Affil_Id':affil["@id"] if "@id" in affil else None,
                    'Affil_Name':affil["affilname"] if "affilname" in affil else None,
                    'Affil_Country':affil["affiliation-country"] if "affiliation-country" in affil else None,
                    'Affil_City':affil["affiliation-city"] if "affiliation-city" in affil else None
                })
        
        if "@has-funding-info" in record['abstracts-retrieval-response']['item']['xocs:meta']['xocs:funding-list']:
            if "xocs:funding" in record['abstracts-retrieval-response']['item']['xocs:meta']['xocs:funding-list']:
                fundings = record['abstracts-retrieval-response']['item']['xocs:meta']['xocs:funding-list']['xocs:funding']
                for funding in fundings:
                    funds.append({
                        'Eid' : eid,
                        'agency-matched-string' : funding["xocs:funding-agency-matched-string"] if "xocs:funding-agency-matched-string" in funding else None,
                        'agency-acronym': funding["xocs:funding-agency-acronym"] if "xocs:funding-agency-acronym" in funding else None,
                        'agency': funding["xocs:funding-agency"] if "xocs:funding-agency" in funding else None,
                        'agency-id': funding["xocs:funding-agency-id"] if "xocs:funding-agency-id" in funding else None,
                        'agency-country': funding["xocs:funding-agency-country"] if "xocs:funding-agency-country" in funding else None
                    })
            else:
                funds.append({
                    'Eid' : eid,
                    'agency-matched-string' : None,
                    'agency-acronym': None,
                    'agency': None,
                    'agency-id': None,
                    'agency-country': None
                })
    except:
        pass

df = pd.DataFrame(rows)

subject_df = pd.DataFrame(subj)

keyword_df = pd.DataFrame(keywords)

affil_df = pd.DataFrame(affiliations)

funds_df = pd.DataFrame(funds)

# %%
df = df.drop_duplicates()
subject_df = subject_df.drop_duplicates()
keyword_df = keyword_df.drop_duplicates()
affil_df = affil_df.drop_duplicates()
funds_df = funds_df.drop_duplicates()

# %%
df
# Out:
#                                                    Title Publish_year  \
# 0      Effects of iron content on the microstructure ...         2018
# 1      The critical factors of research and innovatio...         2018
# 2      Is the occiput-wall distance valid and reliabl...         2018
# 3      Comparison of soil composition between farmlan...         2018
# 4      The impact of wire caliber on ERCP outcomes: a...         2018
# ...                                                  ...          ...
# 20211  A Techno-Economic Assessment of a Second-Life ...         2023
# 20212  Encouraging green product purchase: Green valu...         2023
# 20213  Does leukocytosis remain a predictive factor f...         2023
# 20214  Administration of ketoprofen in postpartum sow...         2023
# 20215  Role of Anxiety in Willingness to Communicate ...         2023
#
#                       Eid Aggregation_type  Author_Count Language
# 0      2-s2.0-85053164279          Journal             7      eng
# 1      2-s2.0-85049101440          Journal             3      eng
# 2      2-s2.0-85054140369          Journal             8      eng
# 3      2-s2.0-85097515350          Journal             2      eng
# 4      2-s2.0-85041527766          Journal            13      eng
# ...                   ...              ...           ...      ...
# 20211  2-s2.0-85152540548          Journal             3      eng
# 20212  2-s2.0-85132634561          Journal             2      eng
# 20213  2-s2.0-85150789915          Journal            16      eng
# 20214  2-s2.0-85165609857          Journal             8      eng
# 20215  2-s2.0-85164405594          Journal             3      eng
#
# [20216 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Title                 0
# Publish_year          0
# Eid                   0
# Aggregation_type      0
# Author_Count          0
# Language            120
# dtype: int64

# %%
subject_df
# Out:
#                       Eid                                       Subject_Area  \
# 0      2-s2.0-85053164279                            Materials Science (all)
# 1      2-s2.0-85053164279                           Condensed Matter Physics
# 2      2-s2.0-85049101440              Business and International Management
# 3      2-s2.0-85049101440          Economics, Econometrics and Finance (all)
# 4      2-s2.0-85054140369  Physical Therapy, Sports Therapy and Rehabilit...
# ...                   ...                                                ...
# 50059  2-s2.0-85165609857                                           Genetics
# 50060  2-s2.0-85165609857                                   Veterinary (all)
# 50061  2-s2.0-85164405594                           Language and Linguistics
# 50062  2-s2.0-85164405594                           Linguistics and Language
# 50063  2-s2.0-85164405594                     Literature and Literary Theory
#
#       Subject_Code
# 0             2500
# 1             3104
# 2             1403
# 3             2000
# 4             3612
# ...            ...
# 50059         1311
# 50060         3400
# 50061         1203
# 50062         3310
# 50063         1208
#
# [50064 rows x 3 columns]

# %%
subject_df.isnull().sum()
# Out:
# Eid             0
# Subject_Area    0
# Subject_Code    0
# dtype: int64

# %%
keyword_df
# Out:
#                       Eid                    Keyword Language Original
# 0      2-s2.0-85053164279                        EIS      eng     None
# 1      2-s2.0-85053164279             Microstructure      eng     None
# 2      2-s2.0-85053164279          Pitting corrosion      eng     None
# 3      2-s2.0-85053164279               Polarization      eng     None
# 4      2-s2.0-85053164279             Titanium alloy      eng     None
# ...                   ...                        ...      ...      ...
# 83027  2-s2.0-85164405594                    anxiety      eng        y
# 83028  2-s2.0-85164405594           cultural beliefs      eng        y
# 83029  2-s2.0-85164405594  fear of committing errors      eng        y
# 83030  2-s2.0-85164405594     Jordanian EFL learners      eng        y
# 83031  2-s2.0-85164405594                        WTC      eng        y
#
# [83014 rows x 4 columns]

# %%
keyword_df.isnull().sum()
# Out:
# Eid             0
# Keyword         0
# Language        0
# Original    24797
# dtype: int64

# %%
affil_df
# Out:
#                        Eid  Affil_Id  \
# 0       2-s2.0-85053164279  60091507
# 1       2-s2.0-85053164279  60018465
# 2       2-s2.0-85054140369  60017165
# 3       2-s2.0-85054140369  60092136
# 4       2-s2.0-85054140369  60028190
# ...                    ...       ...
# 197265  2-s2.0-85150789915  60006964
# 197266  2-s2.0-85150789915  60005255
# 197267  2-s2.0-85150789915  60002620
# 197268  2-s2.0-85164405594  60105841
# 197269  2-s2.0-85164405594  60028190
#
#                                                Affil_Name Affil_Country  \
# 0       Metallurgy and Materials Research Institute Ch...      Thailand
# 1                                      Yanshan University         China
# 2                                    Khon Kaen University      Thailand
# 3               Rajamangala University of Technology Isan      Thailand
# 4                                Chulalongkorn University      Thailand
# ...                                                   ...           ...
# 197265                Phramongkutklao College of Medicine      Thailand
# 197266                                 Rajavithi Hospital      Thailand
# 197267      Faculty of Medicine, Chulalongkorn University      Thailand
# 197268                    Al-Hussein Bin Talal University        Jordan
# 197269                           Chulalongkorn University      Thailand
#
#                Affil_City
# 0                 Bangkok
# 1             Qinhuangdao
# 2               Khon Kaen
# 3       Nakhon Ratchasima
# 4                 Bangkok
# ...                   ...
# 197265            Bangkok
# 197266            Bangkok
# 197267            Bangkok
# 197268              Ma'an
# 197269            Bangkok
#
# [196832 rows x 5 columns]

# %%
affil_df.isnull().sum()
# Out:
# Eid                0
# Affil_Id           0
# Affil_Name         0
# Affil_Country    102
# Affil_City       847
# dtype: int64

# %%
funds_df['agency-id'].head(5).to_list()
# Out:
# [None,
#  None,
#  'http://data.elsevier.com/vocabulary/SciValFunders/501100001809',
#  'http://data.elsevier.com/vocabulary/SciValFunders/501100002873',
#  'http://data.elsevier.com/vocabulary/SciValFunders/501100008095']

# %%
funds_df.head(5)
# Out:
#                   Eid                              agency-matched-string  \
# 0  2-s2.0-85053164279               Ratchadapisek Sompoch Endowment Fund
# 1  2-s2.0-85053164279  Surface Coatings Technology for Metals and Mat...
# 2  2-s2.0-85053164279                                               NSFC
# 3  2-s2.0-85053164279                           Chulalongkorn University
# 4  2-s2.0-85053164279                                 Yanshan University
#
#   agency-acronym                                        agency  \
# 0           None                                          None
# 1           None                                          None
# 2           NSFC  National Natural Science Foundation of China
# 3             CU                      Chulalongkorn University
# 4            YSU                            Yanshan University
#
#                                            agency-id  \
# 0                                               None
# 1                                               None
# 2  http://data.elsevier.com/vocabulary/SciValFund...
# 3  http://data.elsevier.com/vocabulary/SciValFund...
# 4  http://data.elsevier.com/vocabulary/SciValFund...
#
#                      agency-country
# 0                              None
# 1                              None
# 2  http://sws.geonames.org/1814991/
# 3  http://sws.geonames.org/1605651/
# 4  http://sws.geonames.org/1814991/

# %%
funding_name_list = funds_df[funds_df['agency-id'].isna()][['agency-matched-string']]['agency-matched-string'].drop_duplicates().dropna().reset_index().drop(columns='index')

# %%
funds_df.to_csv('aj_funding_data.csv', index=False)

# %%
# funding_name_list.to_csv('funding_name_list.csv', index=False)

# %%
funds_df.isnull().sum()
# Out:
# Eid                          0
# agency-matched-string     3045
# agency-acronym           27394
# agency                   20554
# agency-id                20342
# agency-country           20615
# dtype: int64

# %%
funds_df['agency-matched-string'].value_counts()
# Out:
# agency-matched-string
# Chulalongkorn University                                4226
# Thailand Research Fund                                  1405
# National Research Council of Thailand                   1060
# Second Century Fund                                      568
# NSTDA                                                    516
#                                                         ...
# Solar Energy Technology Office                             1
# Villum Foundation                                          1
# National Renewable Energy Laboratory                       1
# United States – Israel Binational Science Foundation       1
# Editor-in-Chief of Hematology                              1
# Name: count, Length: 10131, dtype: int64

# %%
funds_df['agency-acronym'].value_counts()
# Out:
# agency-acronym
# CU            4358
# TRF           1501
# NRCT          1147
# สวทช           843
# MOST           619
#               ...
# FU Berlin        1
# NSTDA;สวทช       1
# GoK              1
# CCH              1
# SNRU             1
# Name: count, Length: 1655, dtype: int64

# %%
funds_df['Eid'].value_counts()
# Out:
# Eid
# 2-s2.0-85123911583    162
# 2-s2.0-85048748130    146
# 2-s2.0-85072850749    141
# 2-s2.0-85070317489    139
# 2-s2.0-85072183946    138
#                      ...
# 2-s2.0-85145168470      1
# 2-s2.0-85066625830      1
# 2-s2.0-85140446464      1
# 2-s2.0-85055718889      1
# 2-s2.0-85117535862      1
# Name: count, Length: 10535, dtype: int64

# %%
# Find rows where all fields except 'Eid' are None
filtered_df = funds_df[funds_df.drop(columns=['Eid']).isna().all(axis=1)]

filtered_df
# Out:
#                       Eid agency-matched-string agency-acronym agency  \
# 10     2-s2.0-85041527766                  None           None   None
# 125    2-s2.0-85020664359                  None           None   None
# 240    2-s2.0-85062171866                  None           None   None
# 252    2-s2.0-85049301587                  None           None   None
# 253    2-s2.0-85050807596                  None           None   None
# ...                   ...                   ...            ...    ...
# 74268  2-s2.0-85133588862                  None           None   None
# 74338  2-s2.0-85162092675                  None           None   None
# 74384  2-s2.0-85165910707                  None           None   None
# 74395  2-s2.0-85151554103                  None           None   None
# 74456  2-s2.0-85152174030                  None           None   None
#
#       agency-id agency-country
# 10         None           None
# 125        None           None
# 240        None           None
# 252        None           None
# 253        None           None
# ...         ...            ...
# 74268      None           None
# 74338      None           None
# 74384      None           None
# 74395      None           None
# 74456      None           None
#
# [1682 rows x 6 columns]

# %%
subject_df['Subject_Area'].value_counts()
# Out:
# Subject_Area
# Multidisciplinary             1088
# Materials Science (all)        907
# Chemistry (all)                905
# Chemical Engineering (all)     755
# Infectious Diseases            753
#                               ...
# Museology                        1
# Emergency Nursing                1
# Chiropractics                    1
# Optometry                        1
# Family Practice                  1
# Name: count, Length: 321, dtype: int64

# %%
subject_df['Subject_Code'].value_counts()
# Out:
# Subject_Code
# 1000    1088
# 2500     907
# 1600     905
# 1500     755
# 2725     753
#         ...
# 1209       1
# 2907       1
# 3602       1
# 3610       1
# 2714       1
# Name: count, Length: 321, dtype: int64

# %%
merge_table = df.merge(subject_df,on='Eid',how='left')
merge_table
# Out:
#                                                    Title Publish_year  \
# 0      Effects of iron content on the microstructure ...         2018
# 1      Effects of iron content on the microstructure ...         2018
# 2      The critical factors of research and innovatio...         2018
# 3      The critical factors of research and innovatio...         2018
# 4      Is the occiput-wall distance valid and reliabl...         2018
# ...                                                  ...          ...
# 50059  Administration of ketoprofen in postpartum sow...         2023
# 50060  Administration of ketoprofen in postpartum sow...         2023
# 50061  Role of Anxiety in Willingness to Communicate ...         2023
# 50062  Role of Anxiety in Willingness to Communicate ...         2023
# 50063  Role of Anxiety in Willingness to Communicate ...         2023
#
#                       Eid Aggregation_type  Author_Count Language  \
# 0      2-s2.0-85053164279          Journal             7      eng
# 1      2-s2.0-85053164279          Journal             7      eng
# 2      2-s2.0-85049101440          Journal             3      eng
# 3      2-s2.0-85049101440          Journal             3      eng
# 4      2-s2.0-85054140369          Journal             8      eng
# ...                   ...              ...           ...      ...
# 50059  2-s2.0-85165609857          Journal             8      eng
# 50060  2-s2.0-85165609857          Journal             8      eng
# 50061  2-s2.0-85164405594          Journal             3      eng
# 50062  2-s2.0-85164405594          Journal             3      eng
# 50063  2-s2.0-85164405594          Journal             3      eng
#
#                                             Subject_Area Subject_Code
# 0                                Materials Science (all)         2500
# 1                               Condensed Matter Physics         3104
# 2                  Business and International Management         1403
# 3              Economics, Econometrics and Finance (all)         2000
# 4      Physical Therapy, Sports Therapy and Rehabilit...         3612
# ...                                                  ...          ...
# 50059                                           Genetics         1311
# 50060                                   Veterinary (all)         3400
# 50061                           Language and Linguistics         1203
# 50062                           Linguistics and Language         3310
# 50063                     Literature and Literary Theory         1208
#
# [50064 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Title                 0
# Publish_year          0
# Eid                   0
# Aggregation_type      0
# Author_Count          0
# Language            120
# dtype: int64

# %%
# filepath = Path('DATA/main.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# df.to_csv(filepath, index=False)

# %%
# filepath = Path('DATA/subject.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# subject_df.to_csv(filepath, index=False)

# %%
# filepath = Path('DATA/keyword.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# keyword_df.to_csv(filepath, index=False)

# %%
# filepath = Path('DATA/funding.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# funds_df.to_csv(filepath, index=False)
