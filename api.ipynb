# %%
import pandas as pd

# %%
df = pd.read_csv('./scopus-2.csv')

# %%
df['Funding Details'].to_list()
# Out:
# [nan,
#  'Helse-Vest, (40415, 911978)',
#  'Rachadaphiseksomphot Fund; Russian State Research Project; Russian Foundation for Basic Research, RFBR, (16–04–00197); Chulalongkorn University, CU; Thailand Research Fund, TRF, (RSA_6080013)',
#  'Department of Mathematics and Computer Science, Faculty of Science, Chulalongkorn University; Development and Promotion of Science and Technology Talents project; Chulalongkorn University, CU; Fundo para o Desenvolvimento das Ciências e da Tecnologia, FDCT; Centre International de Mathématiques et Informatique de Toulouse, CIMI; Faculty of Science, Chiang Mai University',
#  nan,
#  'Chulalongkorn University, CU',
#  'Bristol-Myers Squibb, BMS; Pfizer; Novartis; Roche; Ariad Pharmaceuticals',
#  'Chulalongkorn University, CU, (RES_57_411_21_076); Thailand Research Fund, TRF, (IRG 5780014); Burapha University, BUU, (23/2555)',
#  nan,
#  'Chulalongkorn University, CU, (IRG 5780014); Thailand Research Fund, TRF, (DPG5880003)',
# ...
